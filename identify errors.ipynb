# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

# %%
df = pd.read_csv("renewable_energy_projects_dirty.csv")
df.head()
# Out:
#    Project_ID                 Project_Name  Country  Capacity_MW  Start_Year  \
# 0         101       Kainji Solar Expansion  Nigeria         50.0      2020.0
# 1         102              Lekki Wind Farm  Nigeria          NaN      2021.0
# 2         103         Bauchi Biomass Plant  Nigeria         12.0         NaN
# 3         104          Nasarawa Mini‑Hydro  Nigeria          5.0      2019.0
# 4         105  Abuja Solar Rooftop Program  Nigeria          3.5      2023.0
#
#                Status  Estimated_Cost_MillionUSD  CO2_Reduction_tons_per_year
# 0         Operational                       75.0                          NaN
# 1  Under Construction                      120.0                      85000.0
# 2            Planning                        NaN                      15000.0
# 3                 NaN                       18.0                       7000.0
# 4         Operational                        5.0                          NaN

# %%
print(df.dtypes)
# Out:
# Project_ID                       int64
# Project_Name                    object
# Country                         object
# Capacity_MW                    float64
# Start_Year                     float64
# Status                          object
# Estimated_Cost_MillionUSD      float64
# CO2_Reduction_tons_per_year    float64
# dtype: object

# %%
missing_values = df.isnull().sum()
print(missing_values[missing_values > 0])
# Out:
# Project_Name                   1
# Capacity_MW                    2
# Start_Year                     1
# Status                         1
# Estimated_Cost_MillionUSD      1
# CO2_Reduction_tons_per_year    2
# dtype: int64

# %%
print(df.describe())
# Out:
#        Project_ID  Capacity_MW   Start_Year  Estimated_Cost_MillionUSD  \
# count    7.000000     5.000000     6.000000                   6.000000
# mean   104.000000    18.100000  2020.833333                  53.000000
# std      2.160247    18.994736     1.471960                  41.761226
# min    101.000000     3.500000  2019.000000                   5.000000
# 25%    102.500000     5.000000  2020.000000                  23.500000
# 50%    104.000000    12.000000  2020.500000                  50.000000
# 75%    105.500000    20.000000  2021.750000                  71.250000
# max    107.000000    50.000000  2023.000000                 120.000000
#
#        CO2_Reduction_tons_per_year
# count                     5.000000
# mean                  38400.000000
# std                   31824.518849
# min                    7000.000000
# 25%                   15000.000000
# 50%                   30000.000000
# 75%                   55000.000000
# max                   85000.000000

# %%
df.boxplot(column=
           ["Estimated_Cost_MillionUSD", "Capacity_MW"])

plt.show()
